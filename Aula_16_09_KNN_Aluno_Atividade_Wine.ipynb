# %% [markdown]
# # Atividade KNN — Wine Dataset
# ## Replicando o pipeline em outro problema
#
# **Mapa:** ML → Supervisionado → Classificação → KNN
#
# O carregamento está pronto. A partir da EDA, o código é seu. Cada etapa deve conter código **e interpretação**.
#
# **Nome:**
# **Matrícula:**

# %% [markdown]
# ## 1. Importações — mesmas ferramentas conceituais utilizadas na demonstração.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 2. Carregamento — o dataset contém características químicas e uma classe conhecida.

# %%
dados=load_wine(as_frame=True)
df=dados.frame.copy()
print(df.shape)
display(df.head())
print(list(dados.target_names))

# %% [markdown]
# ## 3. Entenda o problema
# Explique o que representa uma linha, identifique target e número de classes e justifique: supervisionado? classificação?
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 4. EDA mínima
# Investigue shape, tipos, ausentes, distribuição do target, estatísticas e faça pelo menos um gráfico Seaborn relacionando features e classes.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 5. X e y
# Separe features e target. Explique por que y não pode permanecer em X.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 6. Treino e teste
# Use 25% para teste, `random_state=42` e estratificação. Explique cada decisão.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 7. KNN sem escala
# Treine KNN com K=5 sem padronização e registre accuracy. Explique por que este não é o pipeline ideal.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 8. Padronização
# Use StandardScaler corretamente: fit apenas no treino. Explique por que fit no conjunto completo é leakage.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 9. KNN padronizado
# Treine KNN K=5, faça predict e calcule accuracy.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 10. Compare escala
# Monte DataFrame + gráfico Seaborn comparando resultados. Explique por que escala afeta KNN.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 11. Abra os vizinhos
# Use `kneighbors()` em uma observação e mostre distâncias, índices/classes e votação.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 12. Valores de K
# Teste K=1,3,5,7,9,11,15; construa DataFrame + lineplot. Explique por que teste não deve virar mecanismo permanente de escolha de K.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 13. Matriz de confusão
# Calcule e desenhe com heatmap. Interprete diagonal e erros.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 14. Métricas
# Mostre classification_report e explique accuracy, precision, recall e F1 com suas palavras.
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 15. Conclusão
# O KNN foi adequado? Qual impacto da escala e de K? Qual erro predominou? O que faltaria antes de produção?
#
# ### Interpretação do aluno

# %%
# SEU CÓDIGO AQUI
